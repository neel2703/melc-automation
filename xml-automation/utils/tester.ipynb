# %%
import pandas as pd
import numpy as np 
import xml
# Out:
# Failed to start the Kernel.
#
# [IPKernelApp] ERROR | Failed to open SQLite history /mnt/datastore/ag_hauser/Neel.Gangrade/.ipython/profile_default/history.sqlite (database is locked).
#
# [IPKernelApp] ERROR | History file was moved to /mnt/datastore/ag_hauser/Neel.Gangrade/.ipython/profile_default/history-corrupt.sqlite and a new file created.
#
# [IPKernelApp] ERROR | Failed to open SQLite history /mnt/datastore/ag_hauser/Neel.Gangrade/.ipython/profile_default/history.sqlite (database is locked).
#
# [IPKernelApp] ERROR | History file was moved to /mnt/datastore/ag_hauser/Neel.Gangrade/.ipython/profile_default/history-corrupt.sqlite and a new file created.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
